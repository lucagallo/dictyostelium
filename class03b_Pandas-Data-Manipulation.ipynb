# %% [markdown]
# ---
#
# # Data Mining:<br>Statistical Modeling and Learning from Data
#
# ## Dr. Ciro Cattuto<br>Dr. Laetitia Gauvin<br>Dr. André Panisson
#
# ### Exercises - Pandas Data Manipulation
#
# ---

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Go to http://quickfacts.census.gov/qfd/download_data.html and download the three files:
#
# - DataSet.txt - 3195 rows, one for the U.S., one for each state, one for each county, but no column headings. Each row is identified by a 5-digit combined state and county code. Data are comma-delimited.
# - DataDict.txt - One row for each column in DataSet.txt. Flat ASCII files have mnemonic identifier, full title, number of decimals, and the U.S. total value (matching the first row of DataDict.txt)
# - FIPS_CountyName.txt - Federal Information Processing Standard codes (FIPS) and corresponding place names.
#
# Copy the files in the same folder you have this notebook.

# %%
dataset_fname = "DataSet.txt"
datadict_fname = "DataDict.txt" 
fips_fname = "FIPS_CountyName.txt"

# %% [markdown]
# ### Load FIPS_CountyName.txt

# %% [markdown]
# Create a fips Series, with FIPS code as key

# %%
# YOUR CODE HERE

# %%
# check NEW YORK state and New York County

print fips['36000'], fips['36061']

# %% [markdown]
# ### EXERCISE: generate a set of FIPS codes that correspond to states

# %%
# YOUR CODE HERE

# %%
# to check

set(states_fips.index) == set([u'01000', u'02000', u'04000', u'05000', u'06000', u'08000',
u'09000', u'10000', u'11000', u'12000', u'13000', u'15000', u'16000', u'17000',
u'18000', u'19000', u'20000', u'21000', u'22000', u'23000', u'24000', u'25000',
u'26000', u'27000', u'28000', u'29000', u'30000', u'31000', u'32000', u'33000',
u'34000', u'35000', u'36000', u'37000', u'38000', u'39000', u'40000', u'41000',
u'42000', u'44000', u'45000', u'46000', u'47000', u'48000', u'49000', u'50000',
u'51000', u'53000', u'54000', u'55000', u'56000'])

# %% [markdown]
# ### EXERCISE: use collections.Counter to check number of counties / state and verify that NY has 62 counties

# %% [markdown]
# http://en.wikipedia.org/wiki/List_of_counties_in_New_York
#
# http://docs.python.org/2/library/collections.html#collections.Counter

# %%
# YOUR CODE HERE

# %%
print counties_count_by_state['36']

# %% [markdown]
# ### EXERCISE: write a function county_fips_for_state that return all county fips for a given state fips

# %%
def county_fips_for_state(state_fips):
    # YOUR CODE HERE

# %%
# check for NY
print [(k, fips[k]) for k in list(county_fips_for_state('36000')) ]

# %% [markdown]
# ## Load dataset

# %%
dataset = pd.read_csv(dataset_fname, dtype={'fips': str}).set_index('fips')
print dataset
# Out:
#        PST045213  PST040210  PST120213  POP010210  AGE135213  AGE295213  \
# fips
# 00000  316128839  308747716        2.4  308745538        6.3       23.3
# 01000    4833722    4779758        1.1    4779736        6.1       23.0
# 01001      55246      54571        1.2      54571        6.1       25.4
# 01003     195540     182265        7.3     182265        5.7       22.4
# 01005      27076      27457       -1.4      27457        5.8       21.1
# 01007      22512      22919       -1.8      22915        5.3       21.3
# 01009      57872      57322        1.0      57322        6.1       23.8
# 01011      10639      10915       -2.5      10914        6.3       21.0
# 01013      20265      20946       -3.3      20947        6.1       23.3
# 01015     116736     118572       -1.5     118572        5.8       22.2
# 01017      34162      34170        0.0      34215        5.9       21.4
# 01019      26203      25986        0.8      25989        4.8       20.7
# 01021      43951      43642        0.7      43643        6.5       24.2
# 01023      13426      13858       -3.1      13859        5.0       21.0
# 01025      25207      25840       -2.4      25833        5.5       23.0
# 01027      13486      13932       -3.2      13932        5.4       21.6
# 01029      14994      14972        0.1      14972        5.5       22.6
# 01031      50938      49948        2.0      49948        6.3       23.7
# 01033      54520      54428        0.2      54428        5.7       21.7
# 01035      12887      13228       -2.6      13228        5.5       21.9
# 01037      10898      11544       -5.6      11539        4.6       18.9
# 01039      37886      37765        0.3      37765        5.9       22.1
# 01041      13986      13906        0.6      13906        6.2       23.0
# 01043      80811      80408        0.5      80406        5.9       22.5
# 01045      49884      50251       -0.7      50251        6.5       23.7
# 01047      41996      43820       -4.2      43820        6.8       25.6
# 01049      71013      71115       -0.1      71109        6.3       24.8
# 01051      80902      79296        2.0      79303        6.0       23.2
# 01053      37983      38319       -0.9      38319        6.3       22.1
# 01055     103931     104427       -0.5     104430        5.8       22.3
# ...          ...        ...        ...        ...        ...        ...
# 55131     132739     131887        0.6     131887        5.5       23.3
# 55133     393843     389891        1.0     389891        5.2       22.7
# 55135      52285      52410       -0.2      52410        5.3       21.6
# 55137      24329      24496       -0.7      24496        4.8       19.0
# 55139     169541     166994        1.5     166994        5.7       21.1
# 55141      73959      74749       -1.1      74749        5.8       22.0
# 56000     582658     563626        3.4     563626        6.6       23.6
# 56001      37422      36299        3.1      36299        5.3       16.3
# 56003      11994      11668        2.8      11668        6.3       25.3
# 56005      48176      46133        4.4      46133        8.2       28.0
# 56007      15748      15885       -0.9      15885        6.2       23.1
# 56009      14313      13833        3.5      13833        6.9       25.1
# 56011       7184       7083        1.4       7083        6.6       23.6
# 56013      40998      40123        2.2      40123        7.5       25.3
# 56015      13612      13249        2.7      13249        5.6       20.0
# 56017       4847       4812        0.7       4812        4.6       20.3
# 56019       8628       8569        0.7       8569        6.0       22.0
# 56021      95809      91738        4.4      91738        6.6       23.6
# 56023      18364      18106        1.4      18106        6.7       27.1
# 56025      80973      75450        7.3      75450        6.6       23.7
# 56027       2541       2484        2.3       2484        4.7       17.8
# 56029      29227      28205        3.6      28205        5.5       20.6
# 56031       8765       8667        1.1       8667        4.9       20.3
# 56033      29824      29116        2.4      29116        5.6       21.3
# 56035      10041      10247       -2.0      10247        6.2       23.8
# 56037      45237      43806        3.3      43806        7.6       27.2
# 56039      22268      21294        4.6      21294        5.9       19.2
# 56041      21066      21118       -0.2      21118        7.6       29.5
# 56043       8463       8533       -0.8       8533        5.8       24.4
# 56045       7158       7208       -0.7       7208        6.3       21.5
#
#        AGE775213  SEX255213  RHI125213  RHI225213    ...      SBO415207  \
# fips                                                 ...
# 00000       14.1       50.8       77.7       13.2    ...            8.3
# 01000       14.9       51.5       69.8       26.6    ...            1.2
# 01001       13.5       51.5       78.1       18.4    ...            0.7
# 01003       18.1       51.2       87.3        9.5    ...            1.3
# 01005       15.9       46.5       50.2       47.6    ...            0.0
# 01007       14.3       46.0       76.3       22.1    ...            0.0
# 01009       16.4       50.6       96.0        1.8    ...            0.0
# 01011       14.6       45.2       27.2       69.9    ...            0.0
# 01013       17.7       53.4       54.3       43.6    ...            0.0
# 01015       15.5       51.7       76.0       20.9    ...            0.5
# 01017       17.8       52.0       58.8       39.1    ...            0.0
# 01019       20.1       50.4       93.2        4.5    ...            0.0
# 01021       14.9       50.8       87.5       10.3    ...            0.0
# 01023       20.3       52.5       56.2       42.7    ...            0.0
# 01025       17.5       52.7       54.1       44.2    ...            0.0
# 01027       19.0       50.8       83.0       14.4    ...            0.0
# 01029       18.0       50.4       94.7        3.6    ...            0.0
# 01031       15.6       50.3       76.7       17.5    ...            0.7
# 01033       18.1       51.9       80.8       16.4    ...            0.0
# 01035       19.7       51.7       52.1       46.0    ...            0.0
# 01037       18.2       50.2       66.5       31.3    ...            0.0
# 01039       19.6       51.6       84.6       12.7    ...            0.0
# 01041       17.5       51.5       71.9       24.1    ...            0.0
# 01043       17.2       50.4       96.2        1.4    ...            0.0
# 01045       14.9       50.5       75.3       19.6    ...            0.0
# 01047       15.3       53.5       29.0       69.6    ...            0.0
# 01049       15.2       50.7       92.4        2.0    ...            0.0
# 01051       13.4       51.4       76.2       21.1    ...            0.0
# 01053       16.2       48.5       62.4       32.2    ...            0.0
# 01055       16.8       51.5       81.3       15.5    ...            0.6
# ...          ...        ...        ...        ...    ...            ...
# 55131       15.1       50.3       96.3        1.0    ...            0.4
# 55133       15.9       50.9       93.9        1.4    ...            1.0
# 55135       19.0       49.6       97.6        0.4    ...            0.8
# 55137       21.8       47.5       95.6        2.1    ...            0.0
# 55139       14.3       49.7       93.1        1.9    ...            0.8
# 55141       18.1       50.7       95.5        0.7    ...            0.0
# 56000       13.5       49.0       92.7        1.7    ...            2.8
# 56001        9.5       47.8       91.7        2.0    ...            3.9
# 56003       18.8       49.5       95.4        1.5    ...            0.0
# 56005        6.7       48.0       94.9        1.1    ...            2.1
# 56007       13.7       45.3       94.1        1.6    ...            0.0
# 56009       13.5       49.1       95.7        1.2    ...            2.6
# 56011       17.4       48.9       96.3        1.2    ...            0.0
# 56013       15.7       50.0       75.0        0.9    ...            2.4
# 56015       19.7       47.7       96.1        1.1    ...            0.0
# 56017       23.0       50.5       95.2        0.9    ...            0.0
# 56019       20.2       49.0       95.3        1.0    ...            0.0
# 56021       13.7       49.7       91.3        3.6    ...            4.7
# 56023       14.3       49.3       96.3        1.0    ...            0.0
# 56025       12.6       49.5       93.7        1.9    ...            2.0
# 56027       20.3       54.0       95.7        1.0    ...            0.0
# 56029       19.2       50.4       95.4        1.5    ...            1.8
# 56031       21.9       49.6       96.4        0.9    ...            0.0
# 56033       17.5       50.0       95.2        1.2    ...            0.0
# 56035       12.3       46.3       95.0        1.4    ...            0.0
# 56037        9.0       47.9       94.2        1.7    ...            3.8
# 56039       11.8       48.0       94.6        1.5    ...            3.3
# 56041       10.5       49.3       95.6        0.8    ...            2.2
# 56043       19.2       49.7       95.0        0.8    ...            0.0
# 56045       17.4       47.6       95.3        0.6    ...            0.0
#
#        SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# fips
# 00000       28.8  5319456312  4174286516  3917663456      12990  613795732
# 01000       28.1   112858843    52252752    57344851      12364    6426342
# 01001       31.7           0           0      598175      12003      88157
# 01003       27.3     1410273           0     2966489      17166     436955
# 01005       27.0           0           0      188337       6334          0
# 01007        0.0           0           0      124707       5804      10757
# 01009       23.2      341544           0      319700       5622      20941
# 01011       38.8           0           0       43810       3995       3670
# 01013        0.0      399132       56712      229277      11326      28427
# 01015       24.7     2679991           0     1542981      13678     186533
# 01017       29.3      667283           0      264650       7620      23237
# 01019       14.5      307439       62293      186321       7613      13948
# 01021        0.0           0      155139      359910       8496      34073
# 01023       44.1           0       52904       84633       5969      11345
# 01025       28.6      571454       85803      344311      13034      23596
# 01027        0.0      330878           0       70558       5123       4352
# 01029       17.7           0        5888      133407       9080       4134
# 01031       29.3      613758      131594      639623      13665      50080
# 01033       22.8     2083166      351388      821284      15040      61935
# 01035       23.0      183544       76736       71232       5430       8667
# 01037        0.0       89585       31647       20531       1904        575
# 01039        0.0      561168      338692      424873      11544      30271
# 01041       30.2      270809      131874       75456       5491       5640
# 01043       23.9     1393437           0      867058      10757     102291
# 01045        0.0      114991       69341      332503       6889      37229
# 01047       28.8     1174763           0      437359      10223      33708
# 01049       25.8     1831626           0      635185       9303      67915
# 01051       28.3      766344      104885      618313       7982      47884
# 01053       21.3      665336       93125      379587      10089      31909
# 01055       25.7     1252962      518424     1114841      10801     137966
# ...          ...         ...         ...         ...        ...        ...
# 55131       19.9     3393434     2800492     1759993      13729     152903
# 55133       24.7    15663482     6882092     5955006      15712     616641
# 55135       24.6     2133603       86158      516629       9929      55597
# 55137       23.9      111250       49841      203004       8226      25080
# 55139       23.4     9198861     1109192     1796479      11126     212069
# 55141       25.3     2562632      893219     1002909      13585      84291
# 56000       25.5     8834810     6352890     8957553      17114    1469008
# 56001       32.2           0      113498      468773      14433      65787
# 56003       30.3           0           0       71008       6242       5611
# 56005       28.2      262454      917314      775117      19157      89245
# 56007       14.7           0       51494      295340      19182      42949
# 56009       26.6           0           0      134349      10436      20947
# 56011       16.8           0       14112       56351       8842       6135
# 56013       22.3           0       76180      558410      14944      66975
# 56015       23.8      147899       52428      116123       9614      11779
# 56017       28.2           0           0       38266       8502      10368
# 56019        0.0           0           0       71779       8868      20749
# 56021       29.8     2420198      628089     1720451      19866     173722
# 56023       21.2           0       26778      221712      13705      21115
# 56025       24.0     1230635     2889434     1377032      19174     167974
# 56027        0.0           0           0       19649       8408       3071
# 56029       22.5       62727      155545      388380      14271     132951
# 56031       33.0           0       34092       93405      11163      12103
# 56033       21.7           0           0      478180      17110      66787
# 56035       17.3           0           0       82792      10563      19746
# 56037       27.2           0      437493      898189      22843     150439
# 56039       25.3           0           0      515644      25688     327363
# 56041       15.9           0      159375      413983      20626      35497
# 56043       26.9           0       12128       98308      12596      10175
# 56045       29.3           0       11540       64312       9395       7520
#
#        BPS030212   LND110210  POP060210
# fips
# 00000     829658  3531905.43       87.4
# 01000      13506    50645.33       94.4
# 01001        385      594.44       91.8
# 01003       1184     1589.78      114.6
# 01005          2      884.88       31.0
# 01007         16      622.58       36.8
# 01009          6      644.78       88.9
# 01011          0      622.81       17.5
# 01013          9      776.83       27.0
# 01015         71      605.87      195.7
# 01017          9      596.53       57.4
# 01019          9      553.70       46.9
# 01021         17      692.85       63.0
# 01023          1      913.50       15.2
# 01025          8     1238.47       20.9
# 01027          0      603.96       23.1
# 01029          1      560.10       26.7
# 01031         91      678.97       73.6
# 01033        166      592.62       91.8
# 01035          1      850.16       15.6
# 01037          0      650.93       17.7
# 01039         13     1030.46       36.6
# 01041          4      608.84       22.8
# 01043         48      734.84      109.4
# 01045         71      561.15       89.6
# 01047         11      978.70       44.8
# 01049         23      777.09       91.5
# 01051        216      618.49      128.2
# 01053          4      945.08       40.5
# 01055         90      534.99      195.2
# ...          ...         ...        ...
# 55131        242      430.70      306.2
# 55133        774      549.57      709.4
# 55135         71      747.71       70.1
# 55137         59      626.15       39.1
# 55139        273      434.49      384.3
# 55141        154      793.12       94.2
# 56000       2110    97093.14        5.8
# 56001        190     4273.84        8.5
# 56003         13     3137.10        3.7
# 56005        179     4802.71        9.6
# 56007         27     7897.58        2.0
# 56009         54     4254.88        3.3
# 56011          7     2854.41        2.5
# 56013         58     9183.81        4.4
# 56015         38     2225.39        6.0
# 56017          0     2004.09        2.4
# 56019          4     4154.15        2.1
# 56021        371     2685.91       34.2
# 56023         28     4076.13        4.4
# 56025        507     5340.35       14.1
# 56027          2     2626.04        0.9
# 56029        124     6942.08        4.1
# 56031         43     2084.21        4.2
# 56033        146     2523.99       11.5
# 56035         26     4886.54        2.1
# 56037        132    10426.65        4.2
# 56039        122     3995.38        5.3
# 56041         38     2081.26       10.1
# 56043          1     2238.55        3.8
# 56045          0     2398.09        3.0
#
# [3195 rows x 51 columns]

# %%
# check the population in the US
print int(dataset.ix['00000']['POP010210']) == 308745538
# Out:
# True

# %% [markdown]
# ### EXERCISE: Show that the sum of all state populations is equal to the population of US

# %%
# YOUR CODE HERE

# %% [markdown]
# ### EXERCISE: Sum up population for all NY counties and verify that they equal NY population

# %%
int(dataset.ix['36000']['POP010210'])  # total 2010 population of NY

# %%
# YOUR CODE HERE

# %% [markdown]
# ### EXERCISE: for each state, list FIPS, state name, population and whether county totals is the same of state total

# %%
# YOUR CODE HERE
